# %%
from __future__ import print_function
import os
import sys
import cv2
from matplotlib import pyplot as plt
from local_config import CURRENT_DIR
try:
    sys.path.append(os.path.join(CURRENT_DIR, ".."))
    import config
    from config import Config
    from inhand_robot import HSRInhandObjectsDataLoader
except:
    print("Failed to load config")

# %%
dt_config = Config()
data_loader = HSRInhandObjectsDataLoader(images_file_path=dt_config.IMAGES_FILE_PATH,
                                         labels_file_path=dt_config.LABELS_FILE_PATH,
                                         classes=dt_config.CLASSES)

# %%
plt.imshow(data_loader.legend)

# %%
plt.figure(figsize=(10,10))
plt.imshow(data_loader.get_overlay_image(1000))
